# %%
from main import initiate_models, run_models
import data
import numpy as np
import matplotlib.pyplot as plt
from fit import get_total_loss, get_subset_loss

# %%
seasonality = data.get_seasonality()
max_val = 0
for key in seasonality.keys():
    val = seasonality[key]
    if val > max_val:
        max_val = val
        
print(1/max_val)
# Out:
# 1.3293082005090684

# %%
loss_list = []
for season_fact in np.arange(1, 1/max_val, .1):
    print("==================")
    print("Season factor ",season_fact)
    print("==================")
    # Collect parameters for fitting
    params_model, _ = data.get_params()

    # Initiate and run models
    models = initiate_models(params_model, season_fact)
    run_models(models)

    # Assign data to patches
    patches = data.assign_data(models)

    print("\nTimepoint N2")    
    t = 1
    tol = .95
    print("Total loss",*get_total_loss(patches, t))
    nr_RL, nr_BR = 0, 0
    hist_RL, hist_BR, hist_RL_data, hist_BR_data = [], [], [], []
    for patch in patches:
        if patch.BR_model[t] < tol*patch.BR_data[t]:
            nr_BR += 1
        if patch.RL_model[t] < tol*patch.RL_data[t]:
            nr_RL += 1
    print("%i of BR patches and %i or RL patches are under the model value"%(nr_BR, nr_RL))
    
    print("\nTimepoint N3") 
    t = 2
    tol = 1
    print("Total loss",*get_total_loss(patches, t))
    nr_RL, nr_BR = 0, 0
    hist_RL, hist_BR, hist_RL_data, hist_BR_data = [], [], [], []
    for patch in patches:
        if patch.BR_model[t] < tol*patch.BR_data[t]:
            nr_BR += 1
        hist_BR.append(patch.BR_model[t])
        hist_BR_data.append(patch.BR_data[t])
        if patch.RL_model[t] < tol*patch.RL_data[t]:
            print(patch.RL_model[t], patch.RL_data[t], patch.id)
            nr_RL += 1
        hist_RL.append(patch.RL_model[t])
        hist_RL_data.append(patch.RL_data[t])
    print("%i of BR patches and %i or RL patches are under the model value"%(nr_BR, nr_RL))

hist_RL, hist_BR, hist_RL_data, hist_BR_data = np.array(hist_RL), np.array(hist_BR), np.array(hist_RL_data), np.array(hist_BR_data)
# Out:
# ==================
# Season factor  1.0
# ==================
#
# Timepoint N2
# Total loss 0.5251683765641555 4.622175674327199
# 0 of BR patches and 34 or RL patches are under the model value
#
# Timepoint N3
# Total loss 0.6994141674066469 5.318452772120442
# 0.674656862777749 1.705 18RP2*
# 1.0418397972681104 1.542 20RP1*
# 0.7946830474541081 0.94 24MP1*
# 3.8781788604469036 3.96 10RG1*
# 3.185742677614132 4.6290000000000004 12RG1*
# 0.678612272421479 1.094 05MP1*
# 2.366875000481659 2.5490000000000004 19RP1*
# 2.720245414074877 3.8819999999999997 10RP1*
# 1.4767213846674119 2.0985 10MG1*
# 1.5521143100322 2.635 11RP2*
# 0.33445900446734705 0.361 22MP1*
# 10.566410253726465 12.062999999999999 04RG1*
# 0.7645945447159741 0.92 12MP1*
# 0.3115026913098712 0.37799999999999995 20MP1*
# 1.6451716680236963 1.6620000000000001 22RG1*
# 0.4449139420861783 0.9990000000000001 21MP1*
# 4.5273866041797035 6.491999999999999 01RG1*
# 1.4102517243550035 1.633 21RP1*
# 0.4176622617823073 0.9009999999999999 18MP1*
# 0.7545644340299505 1.5390000000000001 04MP1*
# 0.5668018153998073 1.159 01MP1*
# 0.5997755038448725 0.9990000000000001 13MP1*
# 0.13784388193679611 0.3 03MP1*
# 1.9817018938026902 2.563 14MP1*
# 1.1393384468700027 1.274 01RP1*
# 0.6301794409068969 0.8860000000000001 23RP1*
# 2.17079435362051 2.322 06RP2*
# 0.2957193001152338 0.335 06MP1*
# 1.543517445639957 1.789 11RP1*
# 0.8225858340118481 0.8520000000000001 23MG1*
# 0.9894755178095971 1.137 11MP2*
# 0 of BR patches and 31 or RL patches are under the model value
# ==================
# Season factor  1.1
# ==================
#
# Timepoint N2
# Total loss 0.5363309818070372 4.9472124929723895
# 0 of BR patches and 30 or RL patches are under the model value
#
# Timepoint N3
# Total loss 0.7385386995571736 5.399334870670189
# 10.951645529062075 12.062999999999999 04RG1*
# 1.181134207571436 1.274 01RP1*
# 0.7822186135137159 1.5390000000000001 04MP1*
# 1.6089917289622242 2.635 11RP2*
# 2.4534267074756824 2.5490000000000004 19RP1*
# 0.32294517148903124 0.37799999999999995 20MP1*
# 0.5875948150977354 1.159 01MP1*
# 1.0800685201718458 1.542 20RP1*
# 0.7926148663362587 0.92 12MP1*
# 3.302632587749355 4.6290000000000004 12RG1*
# 2.053868904936242 2.563 14MP1*
# 0.46124578990913634 0.9990000000000001 21MP1*
# 0.14291186140404796 0.3 03MP1*
# 2.2502161262632456 2.322 06RP2*
# 1.46194952851219 1.633 21RP1*
# 0.6217743879160413 0.9990000000000001 13MP1*
# 1.6000810887635317 1.789 11RP1*
# 0.3065828910172413 0.335 06MP1*
# 0.6533274986988894 0.8860000000000001 23RP1*
# 1.5309154510693794 2.0985 10MG1*
# 2.8196280742637083 3.8819999999999997 10RP1*
# 4.693311681082295 6.491999999999999 01RG1*
# 1.0256949514448208 1.137 11MP2*
# 0.8238014999740503 0.94 24MP1*
# 0.7034926341853617 1.094 05MP1*
# 0.34674328746707284 0.361 22MP1*
# 0.4329959154105678 0.9009999999999999 18MP1*
# 0.6994358431622104 1.705 18RP2*
# 0 of BR patches and 28 or RL patches are under the model value
# ==================
# Season factor  1.2000000000000002
# ==================
#
# Timepoint N2
# Total loss 0.5477777010557257 5.214974188700569
# 0 of BR patches and 28 or RL patches are under the model value
#
# Timepoint N3
# Total loss 0.7810813283159502 5.450147385432949
# 0.4781699704548913 0.9990000000000001 21MP1*
# 1.1196826313728094 1.542 20RP1*
# 1.5870740764035198 2.0985 10MG1*
# 3.4237580758896415 4.6290000000000004 12RG1*
# 0.44888585871779507 0.9009999999999999 18MP1*
# 2.922580379045648 3.8819999999999997 10RP1*
# 0.8108724914428113 1.5390000000000001 04MP1*
# 1.6679247982389807 2.635 11RP2*
# 1.5155171866387371 1.633 21RP1*
# 0.7251145426290742 1.705 18RP2*
# 1.658689134913478 1.789 11RP1*
# 0.3594736234590278 0.361 22MP1*
# 0.3348032386723313 0.37799999999999995 20MP1*
# 0.6091409765572493 1.159 01MP1*
# 11.350658647798372 12.062999999999999 04RG1*
# 0.8539721371259231 0.94 24MP1*
# 2.543093047728577 2.5490000000000004 19RP1*
# 2.128610859293777 2.563 14MP1*
# 0.8216480148301838 0.92 12MP1*
# 4.865234948656868 6.491999999999999 01RG1*
# 1.224443843854462 1.274 01RP1*
# 0.3178411095316994 0.335 06MP1*
# 0.7292731444593749 1.094 05MP1*
# 0.14816424526436656 0.3 03MP1*
# 0.6445698353907646 0.9990000000000001 13MP1*
# 0.6773162543075227 0.8860000000000001 23RP1*
# 1.063220459964342 1.137 11MP2*
# 0 of BR patches and 27 or RL patches are under the model value
# ==================
# Season factor  1.3000000000000003
# ==================
#
# Timepoint N2
# Total loss 0.5599351184177052 5.432489026845144
# 0 of BR patches and 28 or RL patches are under the model value
#
# Timepoint N3
# Total loss 0.8275837606408585 5.481851534984463
# 0.8405615543794158 1.5390000000000001 04MP1*
# 0.8852322755698858 0.94 24MP1*
# 1.6452673999919352 2.0985 10MG1*
# 0.4653519849467866 0.9009999999999999 18MP1*
# 0.6314671455240143 1.159 01MP1*
# 0.15360766820388164 0.3 03MP1*
# 3.0292273482098966 3.8819999999999997 10RP1*
# 0.4957076532783135 0.9990000000000001 21MP1*
# 0.3470917889433573 0.37799999999999995 20MP1*
# 0.7559858095194032 1.094 05MP1*
# 1.571021145734224 1.633 21RP1*
# 1.1607315614111722 1.542 20RP1*
# 0.8517299348376121 0.92 12MP1*
# 11.763927816385646 12.062999999999999 04RG1*
# 5.043369326276496 6.491999999999999 01RG1*
# 1.1020981653715853 1.137 11MP2*
# 0.32950810534710395 0.335 06MP1*
# 1.2693213130039598 1.274 01RP1*
# 0.7021758389121178 0.8860000000000001 23RP1*
# 3.5492702338895983 4.6290000000000004 12RG1*
# 2.2060166824826504 2.563 14MP1*
# 0.6681902184971799 0.9990000000000001 13MP1*
# 0.7517251920984062 1.705 18RP2*
# 1.728986453273524 2.635 11RP2*
# 1.7194141273144992 1.789 11RP1*
# 0 of BR patches and 25 or RL patches are under the model value
# ==================
# Season factor  1.4000000000000004
# ==================

# %%
diff = hist_RL - hist_RL_data
diff = diff[~np.isnan(diff)]
plt.hist(diff)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-66f06d349b33> in <module>()
#       2 diff = diff[~np.isnan(diff)]
#       3 plt.hist(diff)
# ----> 4 plt.show()
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py in show(*args, **kw)
#     251     """
#     252     global _show
# --> 253     return _show(*args, **kw)
#     254
#     255
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/backend_bases.py in show(cls, block)
#     206                 block = True
#     207         if block:
# --> 208             cls.mainloop()
#     209
#     210     # This method is the one actually exporting the required methods.
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/backends/_backend_tk.py in mainloop()
#    1071     @staticmethod
#    1072     def mainloop():
# -> 1073         Tk.mainloop()
#
# ~/anaconda3/lib/python3.6/tkinter/__init__.py in mainloop(n)
#     555 def mainloop(n=0):
#     556     """Run the main loop of Tcl."""
# --> 557     _default_root.tk.mainloop(n)
#     558
#     559 getint = int
#
# KeyboardInterrupt:

# %%
nr_RL = 0
for patch in patches:
    if 'R' in patch.id or 'M' in patch.id:
        nr_RL += 1

print(len(patches))
print(nr_RL)
